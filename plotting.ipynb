# %%
import pandas as pd
import matplotlib.pyplot as plt
from utils import plot_m_and_u

# %%
training_rule_change = pd.read_csv('outputs/diff_training_rules.csv')
no_changes = pd.read_csv('outputs/first_test.csv')
less_data = pd.read_csv('outputs/less_data.csv')
less_data2 = pd.read_csv('outputs/less_data2.csv')
linking_subsets = pd.read_csv('outputs/linking.csv')
linking_subsets2 = pd.read_csv('outputs/linking2.csv')
main_to_subset_link = pd.read_csv('outputs/main_to_subset.csv')
main_to_subset_link2 = pd.read_csv('outputs/main_to_subset2.csv')

# %%
fig , ax = plt.subplots()

plot_m_and_u(less_data,ax,'v')
plot_m_and_u(no_changes,ax,'.')
plt.legend()
plt.show()

# %%
fig , ax = plt.subplots()

plot_m_and_u(linking_subsets,ax,'v')
plot_m_and_u(no_changes,ax,'.')
plt.legend()
plt.show()

# %%
fig , ax = plt.subplots()

plot_m_and_u(linking_subsets,ax,'v')
plot_m_and_u(linking_subsets2,ax,'.')
plt.legend()
plt.show()

# %%
fig , ax = plt.subplots()

plot_m_and_u(no_changes,ax,'v')
plot_m_and_u(main_to_subset_link,ax,'.')
plt.legend()
plt.show()

# %%
fig , ax = plt.subplots()

plot_m_and_u(main_to_subset_link,ax,'v')
plot_m_and_u(main_to_subset_link2,ax,'.')
plt.legend()
plt.show()

# %%
fig , ax = plt.subplots()

plot_m_and_u(less_data,ax,'v')
plot_m_and_u(less_data2,ax,'.')
plt.legend()
plt.show()
